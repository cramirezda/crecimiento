# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Replace with the actual path to your file in Google Drive
file_path = '/content/drive/My Drive/Crecimiento/conjunto_de_datos_gastoshogar_enigh2022_ns.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     folioviv  foliohog clave tipo_gasto  mes_dia  forma_pag1  forma_pag2  \
# 0  100005002         1  A004         G1     1109           1           0
# 1  100005002         1  A015         G1     1113           1           0
# 2  100005002         1  A019         G1     1113           1           0
# 3  100005002         1  A052         G1     1113           1           0
# 4  100005002         1  A075         G1     1110           1           0
#
#    forma_pag3  lugar_comp  orga_inst  ...  num_pagos  ultim_pago  gasto_tri  \
# 0           0           5          0  ...                            308.57
# 1           0           6          0  ...                            745.71
# 2           0           6          0  ...                            411.42
# 3           0           6          0  ...                            617.14
# ...

# %%
## convert data from row gasto_tri in float type
df['gasto_tri'] = pd.to_numeric(df['gasto_tri'], errors='coerce').astype(float)

# %%
df['gasto_tri_sum']=df.groupby('folioviv')['gasto_tri'].transform('sum')

# %%
## Create a new column with the first character of column 'clave'
df['tipo'] = df['clave'].str[0]

# %%
df_tipo=df.groupby(['folioviv','tipo']).agg({'gasto_tri':'sum'})
df_tipo
# Out:
#                  gasto_tri
# folioviv   tipo
# 100005002  A       9514.19
#            C       2075.80
#            D        673.53
#            E       2903.22
#            F       3919.34
# ...                    ...
# 3260797912 H        508.69
#            J       1956.50
#            K        391.30
#            L       3913.04
#            R       1810.00
#
# [814479 rows x 1 columns]

# %%
##from df['folioviv'] make a list of the values without repetition
folioviv_list = df['folioviv'].unique().tolist()
df1=pd.DataFrame(folioviv_list,columns=['folioviv'])
df2=pd.DataFrame([df['folioviv'],df['gasto_tri_sum']])
df2=df2.transpose()
df2
# Out:
#              folioviv  gasto_tri_sum
# 0        1.000050e+08       32776.89
# 1        1.000050e+08       32776.89
# 2        1.000050e+08       32776.89
# 3        1.000050e+08       32776.89
# 4        1.000050e+08       32776.89
# ...               ...            ...
# 5075169  3.260798e+09       30166.09
# 5075170  3.260798e+09       30166.09
# 5075171  3.260798e+09       30166.09
# 5075172  3.260798e+09       30166.09
# 5075173  3.260798e+09       30166.09
#
# [5075174 rows x 2 columns]

# %%
df3=pd.merge(df1,df2,on='folioviv',how='left')
df3
#drop repeatede values
df3=df3.drop_duplicates(subset=['folioviv'])
df3
# Out:
#            folioviv  gasto_tri_sum
# 0         100005002       32776.89
# 39        100005003       78670.73
# 73        100005004      101647.27
# 113       100012002       73630.16
# 191       100012004       51176.07
# ...             ...            ...
# 5074921  3260797907       35034.05
# 5074992  3260797908       13198.75
# 5075025  3260797909       18702.34
# 5075060  3260797910      117455.55
# 5075126  3260797912       30166.09
#
# [88823 rows x 2 columns]

# %%
#drop values 0 in df3['gasto_tri_sum']
df3=df3[df3['gasto_tri_sum']!=0]
df3
# Out:
#            folioviv  gasto_tri_sum
# 0         100005002       32776.89
# 39        100005003       78670.73
# 73        100005004      101647.27
# 113       100012002       73630.16
# 191       100012004       51176.07
# ...             ...            ...
# 5074921  3260797907       35034.05
# 5074992  3260797908       13198.75
# 5075025  3260797909       18702.34
# 5075060  3260797910      117455.55
# 5075126  3260797912       30166.09
#
# [88754 rows x 2 columns]

# %%
#expense distribution. Order the data
df3=df3.sort_values(by='gasto_tri_sum')

# %%
#plot distribution

# %%
poverty_line=25906.005
#Count poverty households
poverty_households=df3[df3['gasto_tri_sum']<poverty_line].shape[0]
poverty_households
# Out:
# 41556

# %%
df_tipo
# Out:
#                  gasto_tri
# folioviv   tipo
# 100005002  A       9514.19
#            C       2075.80
#            D        673.53
#            E       2903.22
#            F       3919.34
# ...                    ...
# 3260797912 H        508.69
#            J       1956.50
#            K        391.30
#            L       3913.04
#            R       1810.00
#
# [814479 rows x 1 columns]

# %%
# Si tu DataFrame tiene el MultiIndex con 'folioviv' y 'tipo', primero conviene "resetear" el índice:
df_reset = df.reset_index()  # Ahora tendrás columnas 'folioviv', 'tipo' y 'gasto_tri'

# Pivotamos para que 'folioviv' quede como índice (filas),
# cada 'tipo' sea una columna distinta,
# y los valores sean 'gasto_tri':
# Use pivot_table and specify an aggregation function (e.g., sum) to handle duplicate entries
df_pivot = df_reset.pivot_table(index='folioviv', columns='tipo', values='gasto_tri', aggfunc='sum')

# df_pivot ahora tiene:
# - Index: folioviv
# - Columnas: cada uno de los tipos de gasto
# - Valores: el gasto trimestral correspondiente (sumados si hay duplicados)

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
# Crear el objeto scaler
scaler = StandardScaler()

# Ajustar el scaler a tus datos y transformarlos.
# Esto devuelve un array con los datos estandarizados.
X_scaled = scaler.fit_transform(df_pivot)

# Convertir el array a un DataFrame, manteniendo el índice y las columnas originales
df_pivot_scaled = pd.DataFrame(X_scaled, index=df_pivot.index, columns=df_pivot.columns)

# Mostrar las primeras filas del DataFrame estandarizado
df_pivot_scaled.head()
# Out:
# tipo              A   B         C         D         E         F         G  \
# folioviv
# 100005002 -0.420702 NaN  0.102597 -0.685795  0.027375 -0.067099 -0.405551
# 100005003  0.293698 NaN  0.361496  0.624827       NaN  0.294486  5.014683
# 100005004  0.364791 NaN -0.125854 -0.155608       NaN  1.407056  0.006857
# 100012002  1.158296 NaN  0.083286  0.846556  0.276541  4.327546 -0.405551
# 100012004 -0.702784 NaN  0.607192 -0.626327  0.802565  2.853394 -0.405551
#
# tipo              H         I         J   K         L   M         N   Q  \
# folioviv
# 100005002  0.063908       NaN  0.109192 NaN       NaN NaN -0.072895 NaN
# 100005003 -0.479077       NaN       NaN NaN       NaN NaN       NaN NaN
# 100005004       NaN       NaN       NaN NaN  1.816314 NaN  4.146772 NaN
# 100012002 -0.267916 -0.291403       NaN NaN       NaN NaN -0.391824 NaN
# 100012004 -0.150275       NaN -0.129855 NaN       NaN NaN  0.236219 NaN
#
# tipo              R         T
# folioviv
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Supongamos que tu DataFrame pivotado se llama df_pivot
# 1. Llenar o eliminar valores nulos
df_pivot_scaled.fillna(0, inplace=True)

# 2. Estandarizar (si consideras necesario)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_pivot_scaled)

# 3. Ajustar el PCA
pca = PCA()
pca.fit(X_scaled)

# Eigenvalores (autovalores)
print("Eigenvalores (autovalores):", pca.explained_variance_)

# Varianza explicada (porcentaje) por cada componente
print("Varianza explicada por cada componente:", pca.explained_variance_ratio_)

# Componentes principales (eigenvectores)
print("Componentes principales (autovectores):\n", pca.components_)
# Out:
# Eigenvalores (autovalores): [3.36308405e+00 1.08950709e+00 1.05493144e+00 1.02296418e+00
#  1.00002833e+00 9.66285040e-01 9.30849452e-01 9.04376220e-01
#  8.93505708e-01 8.59504733e-01 8.17807968e-01 7.68188633e-01
#  6.81444980e-01 5.87837396e-01 5.61102966e-01 4.98761950e-01
#  1.11022302e-16]
# Varianza explicada por cada componente: [2.10190386e-01 6.80934268e-02 6.59324727e-02 6.39345416e-02
#  6.25010667e-02 6.03921351e-02 5.81774358e-02 5.65228774e-02
#  5.58434780e-02 5.37184411e-02 5.11124226e-02 4.80112490e-02
#  4.25898318e-02 3.67394236e-02 3.50685405e-02 3.11722709e-02
#  6.93881578e-18]
# Componentes principales (autovectores):
#  [[ 3.73134874e-01  2.48632770e-03  3.60192745e-01  3.86401204e-01
#    2.05371234e-01  3.36038200e-01  1.73171863e-01  3.56351872e-01
#    1.44781565e-01  1.38803832e-01  9.86292500e-02  1.64694616e-01
#    1.19289416e-01  2.15620179e-01  0.00000000e+00  3.43066664e-01
#    1.18946631e-01]
# ...
